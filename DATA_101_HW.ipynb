# %% [markdown]
# # Homework 1: Python Basics

# %% [markdown]
# ### **Adam Yang - M20821102**
# ### *DATA 101 - Fall 2026*
#
# **Topics in Data Science I'm Excited to learn about**
# 1. Programming in Python
# 2. Data Wrangling & Cleaning
# 3. Logistic Regression & Classification
#
# | Course | Credit | Day/Time | Location |
# |:------:|:------:|:---------:|:---------:|
# |DATA 101|3| T/TR - 12:30-1:45 PM| Rockville Campus|
# |DATA 110|3| T/TR - 6-7:30 PM| Distance Learning|
# |MATH 150|4| M/W - 12-1:30 PM| Takoma Park Campus|
# |PHIL 140|3| Asynchronous| Distance Learning|

# %%
product = 'iPad'
price = 1199.99
quantity = 5
int_result = int(price)
print(int_result)
print (f"We have {quantity} units of {product} available at ${int_result} each.")
# Out:
# 1199
# We have 5 units of iPad available at $1199 each.

# %%
total_inventory_value=price*quantity
print(total_inventory_value)
if total_inventory_value > 500:
    print('True')

#I calculated the total inventory value by multiplying the price by the quantity
#I then checked if the total value was greater than 500 and printed 'True' if it was
# Out:
# 5999.95
# True
